# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.cars.com/shopping/results/?dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=all&mileage_max=&monthly_payment=&page_size=20&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip='

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-spark" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Certified Used Mercedes-benz for Sale Nationwide | Cars.com</title>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 9,990 Mercedes-Benz models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Certified Used Mercedes-benz for Sale Nationwide | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results/" property="og:url"/>
# ...

# %%
results = soup.find_all('div', {'class': 'vehicle-card ep-theme-hubcap'})

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# <div class="vehicle-card ep-theme-hubcap" data-listing-id="e0e684e4-9fd2-4b78-8a1f-b8aaacf0ea59" data-override-payload='{"sponsored_type":"standard","vertical_position":2}' data-tracking-id="2" data-tracking-type="srp-vehicle-card" id="vehicle-card-e0e684e4-9fd2-4b78-8a1f-b8aaacf0ea59" phx-hook="VehicleCard" phx-target="8" trc="" trid="meyosr9q7Ftmow7PwUAa8q" trsi="" trv="">
# <a class="image-gallery-link vehicle-card-visited-tracking-link" data-listing-id="e0e684e4-9fd2-4b78-8a1f-b8aaacf0ea59" href="/vehicledetail/e0e684e4-9fd2-4b78-8a1f-b8aaacf0ea59/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <cars-filmstrip totalcount="17">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 17 of 2020 Mercedes-Benz GLC 350e Base 4MATIC" class="image-wrap" data-index="0">
# ...

# %%
results[0].find('h2').get_text()
# Out:
# '2020 Mercedes-Benz GLC 350e Base 4MATIC'

# %%
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '24,993 mi.'

# %%
results[0].find('span',{'class':'sds-rating__count'}).get_text()
# Out:
# '4.7'

# %%
results[0].find('span',{'class':'test1 sds-rating__link sds-button-link'}).get_text()
# Out:
# '(285 reviews)'

# %%
results[0].find('span',{'class':'primary-price'}).get_text()
# Out:
# '$32,998'

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of Nanuet'

# %%
name = []
mileage = []
rating = []
rating_count = []
dealer_name = []
price = []

for result in results:

    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('N/A')

    #mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('N/A')

    #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('N/A')

    #rating_count
    try:
        rating_count.append(result.find('span',{'class':'test1 sds-rating__link sds-button-link'}).get_text())
    except:
        rating_count.append('N/A')

    #dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('N/A')

    #price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('N/A')

# %%
car_dealer = pd.DataFrame({'Name':name, 'Mileage': mileage, 'Dealer Name': dealer_name, 'Rating': rating, 'Rating Count': rating_count,
                          'Price': price})

# %%
car_dealer
# Out:
#                                          Name     Mileage  \
# 0     2020 Mercedes-Benz GLC 350e Base 4MATIC  24,993 mi.
# 1            2020 Mercedes-Benz S-Class S 560  48,750 mi.
# 2        2023 Mercedes-Benz AMG E 53 E 53 AMG   1,233 mi.
# 3           2023 Mercedes-Benz S-Class 4MATIC   5,147 mi.
# 4      2023 Mercedes-Benz GLA 250 Base 4MATIC   8,485 mi.
# 5          2023 Mercedes-Benz AMG G 63 4MATIC   6,061 mi.
# 6        2023 Mercedes-Benz AMG GLE 53 4MATIC  21,501 mi.
# 7         2021 Mercedes-Benz AMG GT AMG GT 43  29,118 mi.
# 8     2022 Mercedes-Benz AMG E 53 Base 4MATIC   3,573 mi.
# 9                 2018 Mercedes-Benz AMG GT R   1,282 mi.
# 10         2023 Mercedes-Benz AMG GLE 53 Base  10,459 mi.
# 11         2017 Mercedes-Benz AMG SLC 43 Base  42,066 mi.
# 12     2022 Mercedes-Benz GLC 300 Base 4MATIC  15,180 mi.
# 13       2023 Mercedes-Benz AMG E 53 E 53 AMG   2,435 mi.
# 14            2023 Mercedes-Benz GLB 250 Base   7,795 mi.
# ...

# %% [markdown]
# ### Data Cleaning

# %%
car_dealer['Rating Count'] = car_dealer['Rating Count'].apply(lambda x:x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                          Name     Mileage  \
# 0     2020 Mercedes-Benz GLC 350e Base 4MATIC  24,993 mi.
# 1            2020 Mercedes-Benz S-Class S 560  48,750 mi.
# 2        2023 Mercedes-Benz AMG E 53 E 53 AMG   1,233 mi.
# 3           2023 Mercedes-Benz S-Class 4MATIC   5,147 mi.
# 4      2023 Mercedes-Benz GLA 250 Base 4MATIC   8,485 mi.
# 5          2023 Mercedes-Benz AMG G 63 4MATIC   6,061 mi.
# 6        2023 Mercedes-Benz AMG GLE 53 4MATIC  21,501 mi.
# 7         2021 Mercedes-Benz AMG GT AMG GT 43  29,118 mi.
# 8     2022 Mercedes-Benz AMG E 53 Base 4MATIC   3,573 mi.
# 9                 2018 Mercedes-Benz AMG GT R   1,282 mi.
# 10         2023 Mercedes-Benz AMG GLE 53 Base  10,459 mi.
# 11         2017 Mercedes-Benz AMG SLC 43 Base  42,066 mi.
# 12     2022 Mercedes-Benz GLC 300 Base 4MATIC  15,180 mi.
# 13       2023 Mercedes-Benz AMG E 53 E 53 AMG   2,435 mi.
# 14            2023 Mercedes-Benz GLB 250 Base   7,795 mi.
# ...

# %%
car_dealer.to_excel('single_page_car.xlsx', index= False)

# %%
  name = []
mileage = []
rating = []
rating_count = []
dealer_name = []
price = []


for i in range(1,11):

    #website in variable
    website = 'https://www.cars.com/shopping/results/?dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=all&mileage_max=&monthly_payment=&page=' + str(i)+ '&page_size=20&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip='
    
    #request to website
    response = requests.get(website)

    #soup object
    soup = BeautifulSoup(response.content, 'html.parser')

    #results
    results = soup.find_all('div', {'class': 'vehicle-card ep-theme-hubcap'})
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('N/A')
    
        #mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('N/A')
    
        #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('N/A')
    
        #rating_count
        try:
            rating_count.append(result.find('span',{'class':'test1 sds-rating__link sds-button-link'}).get_text())
        except:
            rating_count.append('N/A')
    
        #dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('N/A')
    
        #price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('N/A')

# %%
car_dealer = pd.DataFrame({'Name':name, 'Mileage': mileage, 'Dealer Name': dealer_name, 'Rating': rating, 'Rating Count': rating_count,
                          'Price': price})

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0      2020 Mercedes-Benz GLC 350e Base 4MATIC  24,993 mi.
# 1             2020 Mercedes-Benz S-Class S 560  48,750 mi.
# 2         2023 Mercedes-Benz AMG E 53 E 53 AMG   1,233 mi.
# 3            2023 Mercedes-Benz S-Class 4MATIC   5,147 mi.
# 4       2023 Mercedes-Benz GLA 250 Base 4MATIC   8,485 mi.
# ..                                         ...         ...
# 195  2021 Mercedes-Benz Maybach GLS 600 4MATIC  28,862 mi.
# 196             2020 Mercedes-Benz SL 550 Base  27,408 mi.
# 197    2020 Mercedes-Benz AMG E 53 Base 4MATIC  37,037 mi.
# 198             2018 Mercedes-Benz AMG GT Base  12,817 mi.
# 199          2018 Mercedes-Benz AMG SL 63 Base  11,395 mi.
#
#                       Dealer Name Rating     Rating Count     Price
# 0         Mercedes-Benz of Nanuet    4.7    (285 reviews)   $32,998
# 1      Mercedes-Benz of Lafayette    N/A    (150 reviews)   $55,803
# ...

# %%
car_dealer['Rating Count'] = car_dealer['Rating Count'].apply(lambda x:x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0      2020 Mercedes-Benz GLC 350e Base 4MATIC  24,993 mi.
# 1             2020 Mercedes-Benz S-Class S 560  48,750 mi.
# 2         2023 Mercedes-Benz AMG E 53 E 53 AMG   1,233 mi.
# 3            2023 Mercedes-Benz S-Class 4MATIC   5,147 mi.
# 4       2023 Mercedes-Benz GLA 250 Base 4MATIC   8,485 mi.
# ..                                         ...         ...
# 195  2021 Mercedes-Benz Maybach GLS 600 4MATIC  28,862 mi.
# 196             2020 Mercedes-Benz SL 550 Base  27,408 mi.
# 197    2020 Mercedes-Benz AMG E 53 Base 4MATIC  37,037 mi.
# 198             2018 Mercedes-Benz AMG GT Base  12,817 mi.
# 199          2018 Mercedes-Benz AMG SL 63 Base  11,395 mi.
#
#                       Dealer Name Rating Rating Count     Price
# 0         Mercedes-Benz of Nanuet    4.7         285    $32,998
# 1      Mercedes-Benz of Lafayette    N/A         150    $55,803
# ...

# %%
car_dealer.to_excel('Multi_page_car.xlsx', index= False)
